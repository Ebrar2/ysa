# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebrar2/ysa/blob/son/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

data = pd.read_csv("student-mat.csv")



X = data.drop(columns=["G3"])
y = data["G3"]



label_encoders = {}
for column in X.select_dtypes(include=["object"]).columns:
    label_encoders[column] = LabelEncoder()
    X[column] = label_encoders[column].fit_transform(X[column])


giris_boyutu =32   # Giriş katmanı boyutu
gizliKatman_boyutu1 = 99    # Gizli katman boyutu
gizliKatman_boyutu2 = 10    # Gizli katman boyutu
cikis_boyutu = 1    # Çıktı katmanı boyutu
learning_rate = 0.1

W1=np.random.randn(gizliKatman_boyutu1,giris_boyutu)
W2=np.random.randn(gizliKatman_boyutu2,gizliKatman_boyutu1)
W3=np.random.randn(cikis_boyutu,gizliKatman_boyutu2)


def jacobian_sigmoid(x):
    x= np.float128(x)
    sigmoid= 1 / (1 + np.exp(-x))
    diag_values = sigmoid * (1 - sigmoid)
    return np.diag(diag_values)


warnings.filterwarnings('ignore')
for epoch in range(200):
  for index,row in X.iterrows():
        # İleri besleme (Forward propagation)
        giris=list(row)
        hedef=y.get(index)
        z1 = np.dot(W1,giris)
        z1 = np.float128(z1)
        a1 = 1 / (1 + np.exp(-z1))  # Sigmoid aktivasyon fonksiyonu
        z2 = np.dot(W2,a1)
        z2 = np.float128(z2)
        a2=1 / (1 + np.exp(-z2))    #doğrusal
        # Hata hesaplama (Loss calculation)
        z3=np.dot(W3,a2)
        a3=z3
        e = hedef-a3
        s3=-2*1*e
        s2=np.dot(jacobian_sigmoid(a2),np.transpose(W3))*s3
        s1=np.dot(np.dot(jacobian_sigmoid(a1),np.transpose(W2)),s2)
        W3=W3-learning_rate*s3*np.transpose(a2)
        W2=W2-learning_rate*s2*np.transpose(a1)
        W1=W1-learning_rate*s1*np.transpose(giris)

        # Geriye yayılma (Backpropagation)


hata=[]
for index,row in X.iterrows():
        # İleri besleme (Forward propagation)
        giris=list(row)
        hedef=y.get(index)
        z1 = np.dot(W1,giris)
        z1 = np.float128(z1)
        a1 = 1 / (1 + np.exp(-z1))  # Sigmoid aktivasyon fonksiyonu
        z2 = np.dot(W2,a1)
        z2 = np.float128(z2)
        a2=1 / (1 + np.exp(-z2))    #doğrusal
        # Hata hesaplama (Loss calculation)
        z3=np.dot(W3,a2)
        a3=z3
        e = hedef-a3
        hata.append(e[0])



print(hata)
min_val = np.min(hata)
max_val = np.max(hata)

num_bins = int((max_val - min_val) / 2) + 1
bins = [min_val + 2 * i for i in range(num_bins + 1)]

frequency = np.histogram(hata, bins=bins)[0]

for i in range(num_bins):
    print(f"{bins[i]:.2f} - {bins[i+1]:.2f}: {frequency[i]}")
# Out:
# [-2.0078756823721683094, -2.0078756823721683094, 1.9921243176278316906, 6.9921243176278316906, 1.9921243176278316906, 6.9921243176278316906, 2.9921243176278316906, -2.0078756823721683094, 10.992124317627831691, 6.9921243176278316906, 0.99212431762783169064, 3.9921243176278316906, 5.9921243176278316906, 2.9921243176278316906, 7.9921243176278316906, 5.9921243176278316906, 5.9921243176278316906, 1.9921243176278316906, -3.0078756823721683094, 1.9921243176278316906, 6.9921243176278316906, 6.9921243176278316906, 7.9921243176278316906, 3.9921243176278316906, -0.00787568237216830936, -0.00787568237216830936, 2.9921243176278316906, 6.9921243176278316906, 2.9921243176278316906, 2.9921243176278316906, 3.9921243176278316906, 8.992124317627831691, 7.9921243176278316906, 3.9921243176278316906, 6.9921243176278316906, -2.0078756823721683094, 9.992124317627831691, 6.9921243176278316906, 2.9921243176278316906, 4.9921243176278316906, 2.9921243176278316906, 3.9921243176278316906, 9.992124317627831691, 2
# ...

# %%
import numpy as np
import pandas as pd
import warnings



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

data = pd.read_csv("/content/student-mat.csv")



X = data.drop(columns=["G3"])
y = data["G3"]



label_encoders = {}
for column in X.select_dtypes(include=["object"]).columns:
    label_encoders[column] = LabelEncoder()
    X[column] = label_encoders[column].fit_transform(X[column])

giris_boyutu =32  # Giriş katmanı boyutu
gizliKatman1_boyutu = 99  # İlk gizli katman boyutu
gizliKatman2_boyutu = 3  # İkinci gizli katman boyutu
cikis_boyutu = 1  # Çıktı katmanı boyutu
learning_rate = 0.1

W1=np.random.randn(gizliKatman1_boyutu, giris_boyutu)
W2=np.random.randn(gizliKatman2_boyutu, gizliKatman1_boyutu)
W3=np.random.randn(cikis_boyutu, gizliKatman2_boyutu)



def jacobian_sigmoid(x):
    x= np.float128(x)
    sigmoid= 1 / (1 + np.exp(-x))
    diag_values = sigmoid * (1 - sigmoid)
    return np.diag(diag_values)

warnings.filterwarnings('ignore')
for epoch in range(1000):
  for index,row in X.iterrows():
        # İleri besleme (Forward propagation)
        giris=list(row)
        hedef=y.get(index)
        z1 = np.dot(W1,giris)
        z1 = np.float128(z1)
        a1 = 1 / (1 + np.exp(-z1))  # Sigmoid aktivasyon fonksiyonu
        z2 = np.dot(W2,a1)
        a2 = 1 / (1 + np.exp(-z2))  # Sigmoid aktivasyon fonksiyonu
        z3 = np.dot(W3,a2)
        a3 = z3  # doğrusal
        # Hata hesaplama (Loss calculation)
        e = hedef-a3
        s3=-2*1*e

        s2=np.dot(jacobian_sigmoid(a2),np.transpose(W3))*s3
        #print(jacobian_sigmoid(a1))
        s1 = np.dot(W2.T, s2) * jacobian_sigmoid(z1).T
        W3=W3-learning_rate*s3*a2
        W2=W2-learning_rate*s2*a1
        W1 = W1 - learning_rate * np.outer(s1, giris).sum(axis=0)


        # Geriye yayılma (Backpropagation)

hata = []
for index, row in X.iterrows():
    giris=list(row)
    hedef=y.get(index)
    z1 = np.dot(W1,giris)
    z1 = np.float128(z1)
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid aktivasyon fonksiyonu
    z2 = np.dot(W2,a1)
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid aktivasyon fonksiyonu
    z3 = np.dot(W3,a2)
    a3 = z3  # doğrusal
    # Hata hesaplama (Loss calculation)
    e = hedef-a3[0]
    hata.append(e)

print(hata)






min_val = np.min(hata)
max_val = np.max(hata)

num_bins = int((max_val - min_val) / 2) + 1
bins = [min_val + 2 * i for i in range(num_bins + 1)]

frequency = np.histogram(hata, bins=bins)[0]

for i in range(num_bins):
    print(f"{bins[i]:.2f} - {bins[i+1]:.2f}: {frequency[i]}")
# Out:
# [-2.0076838865573184588, -2.0076838865573184588, 1.9923161134426815412, 6.9923161134426815412, 1.9923161134426815412, 6.9923161134426815412, 2.9923161134426815412, -2.0076838865573184588, 10.992316113442681541, 6.9923161134426815412, 0.99231611344268154124, 3.9923161134426815412, 5.9923161134426815412, 2.9923161134426815412, 7.9923161134426815412, 5.9923161134426815412, 5.9923161134426815412, 1.9923161134426815412, -3.0076838865573184588, 1.9923161134426815412, 6.9923161134426815412, 6.9923161134426815412, 7.9923161134426815412, 3.9923161134426815412, -0.0076838865573184587585, -0.0076838865573184587585, 2.9923161134426815412, 6.9923161134426815412, 2.9923161134426815412, 2.9923161134426815412, 3.9923161134426815412, 8.992316113442681541, 7.9923161134426815412, 3.9923161134426815412, 6.9923161134426815412, -2.0076838865573184588, 9.992316113442681541, 6.9923161134426815412, 2.9923161134426815412, 4.9923161134426815412, 2.9923161134426815412, 3.9923161134426815412, 9.99231611344268154
# ...
